# %%
# Out:
# ['sharath', 14.6, 17151]
# [14.6, 17151, 1234]
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipykernel_55/1866003733.py in <cell line: 0>()
#       6 print(list)
#       7
# ----> 8 print.list
#       9
#      10
#
# AttributeError: 'builtin_function_or_method' object has no attribute 'list'

# %%
class Stack:
    def __init__(self):
        self.stack = []

    def  push(self,item):
        self.stack.append[item]
        print(f"Pushed {item}")

    def pop(slef, item):
        self.pop
